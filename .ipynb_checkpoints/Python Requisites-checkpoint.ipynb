# %% [markdown]
# ## Python Basics

# %%
a=True
type(a)
# Out:
# bool

# %%
#list
l=range(1,100)

#Output lb 1 to ub-1

# %%
res=0

# %%
#LOOP
for i in l:
    res+=i
print(res)

# %%
#Sum of even numbers
for i in l:
    if(i%2==0):
        res+=i
print(res)
